# %%
# Import Libraries
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pandas.api.types import CategoricalDtype
import re
# Data is stored in external directory
path = "../data/cleaned_data/grad_cafe_admissions_updated.csv"
savePath="../data/cleaned_data/dataGroupByUniversity/"
fields = []
rows = []
 
# Import data
# reading csv file
with open(path, 'r') as csvfile:
    # creating a csv reader object
    csvreader = csv.reader(csvfile)
     
    # extracting field names through first row
    fields = next(csvreader)
 
    # extracting each data row one by one
    for row in csvreader:
        rows.append(row)
# Convert into dataframe
df = pd.DataFrame (rows, columns = fields)

# %%
df.head()
# Out:
#   submissionId submissionDate                          institution  \
# 0            1     2006-02-08  Pennsylvania State University (PSU)
# 1            4     2006-02-10          Ohio State University (OSU)
# 2            9     2006-02-10      University Of Colorado, Boulder
# 3           12     2006-02-10                    Purdue University
# 4           17     2006-02-10      Indiana University, Bloomington
#
#                            major   degree  sem notif_result    notif_method  \
# 0              Political Science      PhD  F06     Rejected  Postal Service
# 1                    Social Work  Masters  F06     Accepted           Phone
# 2            Clinical Psychology       NA  F06    Interview           Phone
# 3            Nuclear Engineering      PhD  F06     Accepted  Postal Service
# 4  Information Science - Masters       NA  F06     Accepted  Postal Service
#
#    notif_date studentType gpa gre_v gre_q gre_w gre_subject
# 0  2006-02-16           O  NA    NA    NA    NA          NA
# 1  2005-11-16           O  NA    NA    NA    NA          NA
# 2  2006-01-26           O  NA    NA    NA    NA          NA
# 3  2006-01-30           O  NA    NA    NA    NA          NA
# 4  2006-01-11           O  NA    NA    NA    NA          NA

# %%
UCLA = df.loc[df['institution'] == 'UCLA']

# %%
for uni in ['UCLA','Brown University','University Of Pennsylvania']:
    filtered_df = df.loc[df['institution'] == uni]
    filtered_df.to_csv(savePath+ uni+'.csv', index=False)
