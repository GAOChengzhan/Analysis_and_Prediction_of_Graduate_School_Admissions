# %% [markdown]
# # College Admission Prediction System
#
# Predict the probability of admission of certain students and the universities to which they apply. The datasets employed by this project contains several parameters which are considered significant during the application for Masters Programs and for our analysis/prediction.
#
# - GRE Scores
# - Undergraduate GPAs
#
# Other parameters, such as TOEFL scores, Statement of Purpose, Letters of Recommendation, etc., are examined but will carry less weight in our analysis

# %% [markdown]
# ## Part I: Import Packages and Modules
#
# Import the necessary packages and custom modules

# %% [markdown]
# **Import the following packages using their common shortened name found in parentheses:**
#
# * `numpy` (`np`)
# * `pandas` (`pd`)
# * `scipy` (`scipy`)
# * `seaborn` (`sns`)
# * `matplotlib.pyplot` (`plt`)
# * `os`

# %%
import numpy as np
import pandas as pd
import scipy
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %% [markdown]
# **Import our modular data cleaning and analysis and visualization scripts:**
#
# * `data_cleaning_wrangling.py`
# * `kaggle_analysis_visualization.py`
# * `grad_cafe_analysis_visualization.py`

# %%
import sys
sys.path.append('../src')

# from data_cleaning_wrangling import Clean
from kaggle_analysis_visualization import KaggleAnalysis
from grad_cafe_analysis_visualization import GradCafeAnalysis

# %% [markdown]
# ## Part II: Perform Kaggle Dataset Visualization
#
# We will preform our visualizations on our cleaned Kaggle datasets

# %%
cleaned_kaggle = '../data/cleaned_data/cleaned_kaggle_grad_admissions.csv'

analysis = KaggleAnalysis(cleaned_kaggle)

# %%
analysis.generate_distribution_plots()

# %%
analysis.generate_heat_map()

# %% [markdown]
# ## Part III: Perform GradCafe Dataset Visualization
#
# We will preform our visualizations on our cleaned GradCafe datasets

# %%
cleaned_grad_cafe = '../data/cleaned_data/cleaned_grad_cafe_admissions.csv'

analysis = GradCafeAnalysis(cleaned_grad_cafe)

# %%
analysis.generate_distribution_plots()
