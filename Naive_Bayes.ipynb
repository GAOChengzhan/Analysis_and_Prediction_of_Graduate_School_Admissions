# %% [markdown]
# ## Naive Bayes Analysis

# %%
# Import Libraries
import csv
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import KFold
import numpy as np
from pandas.api.types import CategoricalDtype
import re
# Data is stored in external directory
path = "../grad_cafe_admissions.csv"
fields = []
rows = []
 
# Import data
# reading csv file
with open(path, 'r') as csvfile:
    # creating a csv reader object
    csvreader = csv.reader(csvfile)
     
    # extracting field names through first row
    fields = next(csvreader)
 
    # extracting each data row one by one
    for row in csvreader:
        rows.append(row)
# Convert into dataframe
df = pd.DataFrame (rows, columns = fields)

# %% [markdown]
# ### 1. Data analysis

# %%
nan_count=list()
for field in fields:
    nan_count.append(df[df[field]=='NA'][field].count())

# %% [markdown]
# ### 1.A. Identifying missing labels per feature

# %%
plt.bar(list(range(len(nan_count))), nan_count)
plt.xticks(list(range(len(nan_count))), fields, rotation=90)
plt.ylabel('Frequency of NA')
plt.title('Missing Labels in Gradcafe dataset')
plt.show()

# %%
# Cleaning dataset
def remove_non_latin(string):
    string = re.sub(r'[^\x41-\x5a|\x61-\x7a]',r'', string)
    string = re.findall('[A-Z][^A-Z]*', string)
    
    return ' '.join(string)
for field in ["institution", "major", "degree", "sem"]:
    df[field] = df[field].apply(remove_non_latin)
df.head()
# Out:
#   submissionId submissionDate                          institution  \
# 0            1     2006-02-08  Pennsylvania State University P S U
# 1            4     2006-02-10          Ohio State University O S U
# 2            9     2006-02-10       University Of Colorado Boulder
# 3           12     2006-02-10                    Purdue University
# 4           17     2006-02-10       Indiana University Bloomington
#
#                          major   degree sem notif_result    notif_method  \
# 0            Political Science     Ph D   F     Rejected  Postal Service
# 1                  Social Work  Masters   F     Accepted           Phone
# 2          Clinical Psychology      N A   F    Interview           Phone
# 3          Nuclear Engineering     Ph D   F     Accepted  Postal Service
# 4  Information Science Masters      N A   F     Accepted  Postal Service
#
#    notif_date studentType gpa gre_v gre_q gre_w gre_subject
# 0  2006-02-16           O  NA    NA    NA    NA          NA
# 1  2005-11-16           O  NA    NA    NA    NA          NA
# 2  2006-01-26           O  NA    NA    NA    NA          NA
# 3  2006-01-30           O  NA    NA    NA    NA          NA
# 4  2006-01-11           O  NA    NA    NA    NA          NA

# %%
# Calculating statistics for every field
field_mean = dict()
field_median = dict()
field_max = [4, 170, 170, 4, 990]
field_min = [0, 130, 130, 0, 220]
print("Statistics of main labels in gradcafe dataset")
for i, field in enumerate(fields[-5:]):
    x = df[df[field].str.isnumeric()][[field]]
    x.replace([np.inf, -np.inf], np.nan, inplace=True)
    x = x[(x.to_numpy().astype(float)<=field_max[i]) & \
          (x.to_numpy().astype(float)>=field_min[i])]
    field_mean[field] = x.to_numpy().astype(float).mean()
    field_median[field] = x.median().iat[0]
    print("Label: {0}:".format(field))
    print("Median: {0}".format(field_median[field]))
    print("Mean: {0} \n".format(field_mean[field]))
# Out:
# Statistics of main labels in gradcafe dataset
# Label: gpa:
# Median: 4.0
# Mean: 3.8449064152021717
#
# Label: gre_v:
# Median: 160.0
# Mean: 159.2575876351383
#
# Label: gre_q:
# Median: 162.0
# Mean: 160.664937596825
#
# Label: gre_w:
# Median: 4.0
# Mean: 3.181466676357293
#
# Label: gre_subject:
# Median: 800.0
# Mean: 792.458537208016

# %% [markdown]
# ### 2.C Training Using Gaussian Naive Bayes

# %%
# One-hot vector
def get_ohv(Z_original, Z_, f):
    Z_temp = np.array(Z_original)
    Z_ohv = np.zeros((Z_temp[:,f].size, Z_[:,f].max()+1))
    
    Z_ohv[np.arange(Z_temp[:,f].size), Z_temp[:,f]]=1
    return Z_ohv

# %% [markdown]
# #### A. Training for Data with no-missing labels

# %%
# Remove rows with NAN object in any rows
df_new = df
df_imputed = df_new[(df_new["gpa"].str.isnumeric()==True) & \
           (df_new["gre_v"].str.isnumeric()==True) & \
           (df_new["gre_q"].str.isnumeric()==True) & \
           (df_new["gre_w"].str.isnumeric()==True) & \
           (df_new["gre_subject"].str.isnumeric()==True) ]
# Remove Field values beyond permissble limits
# Mean is used to fill empty cells
for i, field in enumerate(fields[-5:]):
    df_imputed.loc[(df_imputed[field].str.isnumeric()==False) & \
                   (df_imputed[field].to_numpy().astype(float)<=field_max[i]) & \
                   (df_imputed[field].to_numpy().astype(float)>=field_min[i]), field]=field_mean[field]
df_imputed.head()
# Out:
# /var/folders/bd/y38b3rb96b90p6bnpfms_2ww0000gn/T/ipykernel_13484/1913669544.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_imputed.loc[(df_imputed[field].str.isnumeric()==False) & \
#       submissionId submissionDate                       institution  \
# 54843        64519     2010-01-12               Stanford University
# 55047        64749     2010-01-15  University Of Michigan Ann Arbor
# 55336        65057     2010-01-21          Florida State University
# 55337        65058     2010-01-21                University Of Iowa
# 55447        65187     2010-01-22         Michigan State University
#
#                        major degree sem notif_result notif_method  notif_date  \
# 54843             Psychology   Ph D   F    Interview       E-mail  2010-01-12
# 55047      Social Psychology   Ph D   F     Rejected       E-mail  2010-01-15
# 55336  Counseling Psychology   Ph D   F    Interview       E-mail  2009-11-23
# 55337  Counseling Psychology   Ph D   F    Interview       E-mail  2010-01-07
# 55447      Social Psychology   Ph D   F    Interview       E-mail  2010-01-19
#
#       studentType gpa gre_v gre_q gre_w gre_subject
# 54843           A   4   164   166     5         780
# 55047           A   4   164   166     5         780
# 55336           U   4   159   155     4         810
# 55337           U   4   159   155     4         810
# 55447           A   4   164   166     5         780

# %%
# Verify dataset. For this dataset only two output labels are considered "Accepted" and "Rejceted"
cats = ["Accepted", "Rejected"]
cat_type = CategoricalDtype(categories=cats, ordered=False)
X = df_imputed[fields[-5:]].to_numpy()
Y_cat = df_imputed[fields[-9]].astype(cat_type)
Y = Y_cat.cat.codes.to_numpy() + 1
Y_labels = Y_cat.cat.categories
Z = list()
Z_label = list()
for field in ["institution", "major", "degree", "sem"]:
    Z_cat = df_imputed[field].astype(CategoricalDtype())
    Z.append(Z_cat.cat.codes.to_numpy())
    Z_label.append(Z_cat.cat.categories)
Z = np.array(Z).T
X.shape, Y.shape, Y_labels, Z.shape
# Out:
# ((1342, 5),
#  (1342,),
#  Index(['Accepted', 'Rejected'], dtype='object'),
#  (1342, 4))

# %%
# K-fold cross Validation
k = 10
# prepare cross validation
kf = KFold(n_splits=k)
# enumerate splits
Score = list()
for i, (train_index, test_index) in enumerate(kf.split(X)):
    clf = GaussianNB()
    X_train = X[train_index][:,:-2]
    for k in range(len(Z_label)):
        X_train = np.hstack((X_train, get_ohv(Z[train_index],Z, k)))
    clf.fit(X_train, Y[train_index])
    X_test = X[test_index][:,:-2]
    for k in range(len(Z_label)):
        X_test = np.hstack((X_test, get_ohv(Z[test_index],Z, k)))
    Score.append(clf.score(X_test, Y[test_index]))
print("Training using Gaussian Naive Bayes(full input vector)")
print(u"Accuracy after 10-fold cross-validation {0:.3f} \u00B1 {1:.3f}%".format(100*np.mean(Score), 100*np.std(Score)))
print("Max accuracy {0:.3f}%".format(np.max(Score)*100))
# Out:
# Training using Gaussian Naive Bayes(full input vector)
# Accuracy after 10-fold cross-validation 28.607 ± 5.390%
# Max accuracy 35.821%

# %% [markdown]
# **Deprecating following code section B. and C.**

# %% [markdown]
# #### B. Using feature Mean for missing labels

# %%
# Remove NAN objects 
df_new = df
df_imputed = df_new[(df_new["gpa"].str.isnumeric()==True) | \
           (df_new["gre_v"].str.isnumeric()==True) | \
           (df_new["gre_q"].str.isnumeric()==True) | \
           (df_new["gre_w"].str.isnumeric()==True) | \
           (df_new["gre_subject"].str.isnumeric()==True) ]
# Remove Field values beyond permissble limits
# Mean is used to fill empty cells
for i, field in enumerate(fields[-5:]):
    df_imputed.loc[(df_imputed[field].str.isnumeric()==False), field] = field_mean[field] 
    df_imputed.loc[(df_imputed[field].to_numpy().astype(float)>=field_max[i]) | \
                   (df_imputed[field].to_numpy().astype(float)<=field_min[i]), field]=field_mean[field]
df_imputed.head()
# Out:
# /var/folders/bd/y38b3rb96b90p6bnpfms_2ww0000gn/T/ipykernel_13469/604907295.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_imputed.loc[(df_imputed[field].str.isnumeric()==False), field] = field_mean[field]
# /var/folders/bd/y38b3rb96b90p6bnpfms_2ww0000gn/T/ipykernel_13469/604907295.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_imputed.loc[(df_imputed[field].to_numpy().astype(float)>=field_max[i]) | \
#       submissionId submissionDate  \
# 54827        64500     2010-01-12
# 54828        64501     2010-01-12
# 54830        64506     2010-01-12
# 54831        64507     2010-01-12
# 54832        64508     2010-01-12
#
#                                           institution  \
# 54827  University Of California San Francisco U C S F
# 54828  University Of California San Francisco U C S F
# 54830                       University College London
# 54831                London School Of Economics L S E
# 54832                                 Carnegie Mellon
#
#                                        major   degree sem notif_result  \
# 54827                           Neuroscience     Ph D   F    Interview
# 54828                           Neuroscience     Ph D   F    Interview
# 54830            International Public Policy  Masters   F     Accepted
# 54831  Master Of Public Administration M P A  Masters   F     Accepted
# 54832       Biological Sciences Neuroscience     Ph D   F    Interview
#
#       notif_method  notif_date studentType       gpa gre_v gre_q     gre_w  \
# 54827        Phone  2010-01-12           A  3.844906   162   163  3.181467
# 54828        Phone  2010-01-12           A  3.844906   160   166  3.181467
# 54830       E-mail  2009-11-26           A  3.844906   154   155  3.181467
# 54831       E-mail  2010-01-11           A  3.844906   154   155  3.181467
# 54832       E-mail  2010-01-12           A  3.844906   165   166  3.181467
#
#       gre_subject
# 54827  792.458537
# 54828  792.458537
# 54830  792.458537
# 54831  792.458537
# 54832  792.458537

# %%
# Verify dataset. For this dataset only two output labels are considered "Accepted" and "Rejceted"
cats = ["Accepted", "Rejected"]
cat_type = CategoricalDtype(categories=cats, ordered=False)
X = df_imputed[fields[-5:]].to_numpy()
Y_cat = df_imputed[fields[-9]].astype(cat_type)
Y = Y_cat.cat.codes.to_numpy() + 1
Y_labels = Y_cat.cat.categories
Z = list()
Z_label = list()
for field in ["institution", "major", "degree", "sem"]:
    Z_cat = df_imputed[field].astype(CategoricalDtype())
    Z.append(Z_cat.cat.codes.to_numpy())
    Z_label.append(Z_cat.cat.categories)
Z = np.array(Z).T
X.shape, Y.shape, Y_labels, Z.shape
# Out:
# ((175987, 5),
#  (175987,),
#  Index(['Accepted', 'Rejected'], dtype='object'),
#  (175987, 4))

# %%
# K-fold cross Validation
k = 10
# prepare cross validation
kf = KFold(n_splits=k)
# enumerate splits
Score = list()
for i, (train_index, test_index) in enumerate(kf.split(X)):
    clf = GaussianNB()
    X_train = X[train_index][:,:-2]
    for k in range(len(Z_label)):
        X_train = np.hstack((X_train, get_ohv(Z[train_index],Z, k)))
    clf.fit(X_train, Y[train_index])
    X_test = X[test_index][:,:-2]
    for k in range(len(Z_label)):
        X_test = np.hstack((X_test, get_ohv(Z[test_index],Z, k)))
print("Training using Gaussian Naive Bayes(full input vector)")
print(u"Accuracy after 10-fold cross-validation {0:.3f} \u00B1 {1:.3f}%".format(100*np.mean(Score), 100*np.std(Score)))
print("Max accuracy {0:.3f}%".format(np.max(Score)*100))

# %% [markdown]
# #### C. Using feature Median for missing labels

# %%
# Remove NAN objects 
df_new = df
df_imputed = df_new[(df_new["gpa"].str.isnumeric()==True) | \
           (df_new["gre_v"].str.isnumeric()==True) | \
           (df_new["gre_q"].str.isnumeric()==True) | \
           (df_new["gre_w"].str.isnumeric()==True) | \
           (df_new["gre_subject"].str.isnumeric()==True) ]
# Remove Field values beyond permissble limits
# Mean is used to fill empty cells
for i, field in enumerate(fields[-5:]):
    df_imputed.loc[(df_imputed[field].str.isnumeric()==False), field] = field_median[field] 
    df_imputed.loc[(df_imputed[field].to_numpy().astype(float)>=field_max[i]) | \
                   (df_imputed[field].to_numpy().astype(float)<=field_min[i]), field]=field_median[field]
df_imputed.head()
# Out:
# /var/folders/bd/y38b3rb96b90p6bnpfms_2ww0000gn/T/ipykernel_2493/4270392296.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_imputed.loc[(df_imputed[field].str.isnumeric()==False), field] = field_median[field]
# /var/folders/bd/y38b3rb96b90p6bnpfms_2ww0000gn/T/ipykernel_2493/4270392296.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_imputed.loc[(df_imputed[field].to_numpy().astype(float)>=field_max[i]) | \
#       submissionId submissionDate  \
# 54827        64500     2010-01-12
# 54828        64501     2010-01-12
# 54830        64506     2010-01-12
# 54831        64507     2010-01-12
# 54832        64508     2010-01-12
#
#                                           institution  \
# 54827  University Of California San Francisco U C S F
# 54828  University Of California San Francisco U C S F
# 54830                       University College London
# 54831                London School Of Economics L S E
# 54832                                 Carnegie Mellon
#
#                                        major   degree sem notif_result  \
# 54827                           Neuroscience     Ph D   F    Interview
# 54828                           Neuroscience     Ph D   F    Interview
# 54830            International Public Policy  Masters   F     Accepted
# 54831  Master Of Public Administration M P A  Masters   F     Accepted
# 54832       Biological Sciences Neuroscience     Ph D   F    Interview
#
#       notif_method  notif_date studentType  gpa gre_v gre_q gre_w gre_subject
# 54827        Phone  2010-01-12           A  4.0   162   163   4.0       800.0
# 54828        Phone  2010-01-12           A  4.0   160   166   4.0       800.0
# 54830       E-mail  2009-11-26           A  4.0   154   155   4.0       800.0
# 54831       E-mail  2010-01-11           A  4.0   154   155   4.0       800.0
# 54832       E-mail  2010-01-12           A  4.0   165   166   4.0       800.0

# %%
# Verify dataset. For this dataset only two output labels are considered "Accepted" and "Rejceted"
cats = ["Accepted", "Rejected"]
cat_type = CategoricalDtype(categories=cats, ordered=False)
X = df_imputed[fields[-5:]].to_numpy()
Y_cat = df_imputed[fields[-9]].astype(cat_type)
Y = Y_cat.cat.codes.to_numpy() + 1
Y_labels = Y_cat.cat.categories
Z = list()
Z_label = list()
for field in ["institution", "major", "degree", "sem"]:
    Z_cat = df_imputed[field].astype(CategoricalDtype())
    Z.append(Z_cat.cat.codes.to_numpy())
    Z_label.append(Z_cat.cat.categories)
Z = np.array(Z).T
X.shape, Y.shape, Y_labels, Z.shape
# Out:
# ((175987, 5),
#  (175987,),
#  Index(['Accepted', 'Rejected'], dtype='object'),
#  (175987, 4))

# %%
# K-fold cross Validation
k = 10
# prepare cross validation
kf = KFold(n_splits=k)
# enumerate splits
Score = list()
for i, (train_index, test_index) in enumerate(kf.split(X)):
    clf = GaussianNB()
    clf.fit(np.hstack((X[train_index], Z[train_index])), Y[train_index])
    Score.append(clf.score(np.hstack((X[test_index], Z[test_index])), Y[test_index]))
print("Training using Gaussian Naive Bayes(full input vector)")
print(u"Accuracy after 10-fold cross-validation {0:.3f} \u00B1 {1:.3f}%".format(100*np.mean(Score), 100*np.std(Score)))
print("Max accuracy {0:.3f}%".format(np.max(Score)*100))
# Out:
# Training using Gaussian Naive Bayes(full input vector)
# Accuracy after 10-fold cross-validation 50.352 ± 0.666%
# Max accuracy 51.702%

# %% [markdown]
# **Conclusion**: It is apparent from the results that the Naive Bayes is not very efficient on the given dataset. Even with no missing labels maximum achieved accuracy is **60%**</br>
# **This means two of the following things:**</br>
# [1]. **Classifier is weak**</br>
# [2]. **There are unrealiable samples in the dataset**</br>

# %% [markdown]
# In the following experiments we will try to single out samples based on a few variables ie. University, Degree Profram, admission year. We will use the influential labels in our Bayes Classifier.

# %% [markdown]
# **1. Per-university Classifier**

# %%
# Per-university samples
f = 0
samples = list()
for i, uni in enumerate(Z_label[f]):
    idx = np.where(Z[:,f] == i)[0]
    samples.append(len(idx))
plt.hist(samples)
plt.xlabel('Number of Samples')
plt.ylabel('Frequency')
plt.title('Histogram for number of samples for University')
# Out:
# Text(0.5, 1.0, 'Histogram for number of samples for University')

# %% [markdown]
# **From the above image it is clear that per-univeristy sample distribution is disproportionate.**

# %%
Results = list()
# Field number
f=0
# min number of samples
min_samples = 10
for i, field in enumerate(Z_label[f]):
    idx = np.where(Z[:,f] == i)[0]
    if len(idx)>min_samples:
        result = dict()
        accuracy = list()
        y_ = list()
        for i, (train_index, test_index) in enumerate(kf.split(idx)):
            clf = GaussianNB()
            X_train = X[idx[train_index]][:,:-2]

            for k in range(len(Z_label)):
                if k != f:
                    X_train = np.hstack((X_train, get_ohv(Z[idx[train_index]],Z, k)))
#             clf.fit(np.hstack((X[idx[train_index]][:,:-2], Z[idx[train_index]][:,:f], Z[idx[train_index]][:, f+1:])), \
#                     Y[idx[train_index]])
            clf.fit(X_train, Y[idx[train_index]])
            X_test = X[idx[test_index]][:,:-2]
            for k in range(len(Z_label)):
                if k != f:
                    X_test = np.hstack((X_test, get_ohv(Z[idx[test_index]],Z,k)))
#             accuracy.append(clf.score(np.hstack((X[idx[test_index]][:,:-2], \
#                                                  Z[idx[test_index]][:,:f], \
#                                                 Z[idx[test_index]][:, f+1:])), Y[idx[test_index]]))
            accuracy.append(clf.score(X_test, Y[idx[test_index]]))
            y_.append(np.sum(Y[idx[train_index]]==1)/len(train_index))
        result['field'] = field
        result['Mean Accuracy'] = np.mean(accuracy)*100
        result['Max Accuracy'] = np.max(accuracy)*100
        result['Std Dev'] = np.std(accuracy)*100
        result['Number of samples'] = len(idx)
        result['verbose']= "{0}: \n Number of samples: {1} Mean Accuracy: {2:.3f}% Std dev: {3:.3f}% Max Accuracy {4:.3f}% \n".\
              format(field, len(idx), np.mean(accuracy)*100, np.std(accuracy)*100, np.max(accuracy)*100)
        result['% Lable'] = np.mean(y_)
        Results.append(result)
Results = sorted(Results, key=lambda x : x['Max Accuracy'], reverse=True)
print('Top 5 university samples with max accuracy')
for i in range(10):
    print(Results[i]['verbose'])
    print(Results[i]['% Lable'])
Results = sorted(Results, key=lambda x : x['Mean Accuracy'], reverse=True)
print("--------------------------\n--------------------------")
print('Top 5 university samples with mean accuracy')
for i in range(5):
    print(Results[i]['verbose'])
    print(Results[i]['% Lable'])
# Out:
# Top 5 university samples with max accuracy
# Brown University:
#  Number of samples: 11 Mean Accuracy: 85.000% Std dev: 32.016% Max Accuracy 100.000%
#
# 0.5455555555555556
# Columbia University:
#  Number of samples: 12 Mean Accuracy: 60.000% Std dev: 48.990% Max Accuracy 100.000%
#
# 0.4154545454545454
# Cornell:
#  Number of samples: 17 Mean Accuracy: 75.000% Std dev: 33.541% Max Accuracy 100.000%
#
# 0.4708333333333334
# Cornell University:
#  Number of samples: 20 Mean Accuracy: 50.000% Std dev: 38.730% Max Accuracy 100.000%
#
# 0.5
# Duke University:
#  Number of samples: 12 Mean Accuracy: 45.000% Std dev: 47.170% Max Accuracy 100.000%
#
# 0.3327272727272727
# Harvard:
#  Number of samples: 17 Mean Accuracy: 55.000% Std dev: 41.533% Max Accuracy 100.000%
#
# 0.35291666666666666
# Harvard University:
#  Number of samples: 28 Mean Accuracy: 45.000% Std dev: 29.861% Max Accuracy 100.000%
#
# 0.35707692307692307
# M I T:
#  Number of samples: 19 Mean Accuracy: 45.000% Std dev: 35.000% Max Accuracy 100.000%
#
# 0.3160130718954248
# Princeton:
#  Number of samples: 12 Mean Accuracy: 55.000% Std dev: 47.170% Max Accuracy 100.000%
#
# 0.16636363636363638
# Stanford University:
#  Number of samples: 37 Mean Accuracy: 53.333% Std dev: 23.921% Max Accuracy 100.000%
#
# 0.45935828877005347
# --------------------------
# --------------------------
# Top 5 university samples with mean accuracy
# U C L A:
#  Number of samples: 16 Mean Accuracy: 90.000% Std dev: 20.000% Max Accuracy 100.000%
#
# 0.31238095238095237
# Brown University:
#  Number of samples: 11 Mean Accuracy: 85.000% Std dev: 32.016% Max Accuracy 100.000%
#
# 0.5455555555555556
# Cornell:
#  Number of samples: 17 Mean Accuracy: 75.000% Std dev: 33.541% Max Accuracy 100.000%
#
# 0.4708333333333334
# U C Berkeley:
#  Number of samples: 27 Mean Accuracy: 68.333% Std dev: 22.913% Max Accuracy 100.000%
#
# 0.6295
# University Of Chicago:
#  Number of samples: 31 Mean Accuracy: 67.500% Std dev: 25.941% Max Accuracy 100.000%
#
# 0.4514550264550265

# %% [markdown]
# **2. Per-program classifier**

# %%
# Per-degree samples
f = 1
samples = list()
for i, uni in enumerate(Z_label[f]):
    idx = np.where(Z[:,f] == i)[0]
    samples.append(len(idx))
plt.hist(samples)
plt.xlabel('Number of Samples')
plt.ylabel('Frequency')
plt.title('Histogram for number of samples for degree program')
# Out:
# Text(0.5, 1.0, 'Histogram for number of samples for degree program')

# %%
Results = list()
# Field number
f=1
# min number of samples
min_samples = 10
for i, field in enumerate(Z_label[f]):
    idx = np.where(Z[:,f] == i)[0]
    if len(idx)>min_samples:
        result = dict()
        accuracy = list()
        y_ = list()
        for i, (train_index, test_index) in enumerate(kf.split(idx)):
            clf = GaussianNB()
            X_train = X[idx[train_index]][:,:-2]

            for k in range(len(Z_label)):
                if k != f:
                    X_train = np.hstack((X_train, get_ohv(Z[idx[train_index]],Z, k)))
#             clf.fit(np.hstack((X[idx[train_index]][:,:-2], Z[idx[train_index]][:,:f], Z[idx[train_index]][:, f+1:])), \
#                     Y[idx[train_index]])
            clf.fit(X_train, Y[idx[train_index]])
            X_test = X[idx[test_index]][:,:-2]
            for k in range(len(Z_label)):
                if k != f:
                    X_test = np.hstack((X_test, get_ohv(Z[idx[test_index]],Z,k)))
#             accuracy.append(clf.score(np.hstack((X[idx[test_index]][:,:-2], \
#                                                  Z[idx[test_index]][:,:f], \
#                                                 Z[idx[test_index]][:, f+1:])), Y[idx[test_index]]))
            accuracy.append(clf.score(X_test, Y[idx[test_index]]))
            y_.append(np.sum(Y[idx[train_index]]==1)/len(train_index))
        result['field'] = field
        result['Mean Accuracy'] = np.mean(accuracy)*100
        result['Max Accuracy'] = np.max(accuracy)*100
        result['Std Dev'] = np.std(accuracy)*100
        result['Number of samples'] = len(idx)
        result['verbose']= "{0}: \n Number of samples: {1} Mean Accuracy: {2:.3f}% Std dev: {3:.3f}% Max Accuracy {4:.3f}% \n".\
              format(field, len(idx), np.mean(accuracy)*100, np.std(accuracy)*100, np.max(accuracy)*100)
        result['% Lable'] = np.mean(y_)
        Results.append(result)
Results = sorted(Results, key=lambda x : x['Max Accuracy'], reverse=True)
print('Top 5 degree programs with highest max accuracy')
for i in range(10):
    print(Results[i]['verbose'])
    print(Results[i]['% Lable'])
Results = sorted(Results, key=lambda x : x['Mean Accuracy'], reverse=True)
print("--------------------------\n--------------------------")
print('Top 5 degree programs with highest mean accuracy')
for i in range(5):
    print(Results[i]['verbose'])
    print(Results[i]['% Lable'])
# Out:
# Top 5 degree programs with highest max accuracy
# Applied Mathematics:
#  Number of samples: 12 Mean Accuracy: 70.000% Std dev: 45.826% Max Accuracy 100.000%
#
# 0.7490909090909091
# Applied Physics:
#  Number of samples: 20 Mean Accuracy: 85.000% Std dev: 22.913% Max Accuracy 100.000%
#
# 0.9
# Computer Science:
#  Number of samples: 21 Mean Accuracy: 26.667% Std dev: 35.119% Max Accuracy 100.000%
#
# 0.47660818713450287
# English Literature:
#  Number of samples: 28 Mean Accuracy: 38.333% Std dev: 38.042% Max Accuracy 100.000%
#
# 0.28584615384615386
# Statistics:
#  Number of samples: 37 Mean Accuracy: 47.500% Std dev: 24.735% Max Accuracy 75.000%
#
# 0.7565953654188948
# Astronomy:
#  Number of samples: 41 Mean Accuracy: 28.500% Std dev: 18.980% Max Accuracy 60.000%
#
# 0.1707957957957958
# English:
#  Number of samples: 151 Mean Accuracy: 35.792% Std dev: 14.413% Max Accuracy 60.000%
#
# 0.3443790849673203
# Mathematics:
#  Number of samples: 101 Mean Accuracy: 30.455% Std dev: 17.890% Max Accuracy 60.000%
#
# 0.45547008547008555
# Clinical Psychology:
#  Number of samples: 66 Mean Accuracy: 21.429% Std dev: 16.007% Max Accuracy 50.000%
#
# 0.2576553672316384
# Physics And Astronomy:
#  Number of samples: 14 Mean Accuracy: 10.000% Std dev: 20.000% Max Accuracy 50.000%
#
# 0.4288461538461538
# --------------------------
# --------------------------
# Top 5 degree programs with highest mean accuracy
# Applied Physics:
#  Number of samples: 20 Mean Accuracy: 85.000% Std dev: 22.913% Max Accuracy 100.000%
#
# 0.9
# Applied Mathematics:
#  Number of samples: 12 Mean Accuracy: 70.000% Std dev: 45.826% Max Accuracy 100.000%
#
# 0.7490909090909091
# Statistics:
#  Number of samples: 37 Mean Accuracy: 47.500% Std dev: 24.735% Max Accuracy 75.000%
#
# 0.7565953654188948
# English Literature:
#  Number of samples: 28 Mean Accuracy: 38.333% Std dev: 38.042% Max Accuracy 100.000%
#
# 0.28584615384615386
# English:
#  Number of samples: 151 Mean Accuracy: 35.792% Std dev: 14.413% Max Accuracy 60.000%
#
# 0.3443790849673203

# %% [markdown]
# **3. Per-degree classifier**

# %%
# Per-degree samples
f = 2
samples = list()
for i, uni in enumerate(Z_label[f]):
    idx = np.where(Z[:,f] == i)[0]
    samples.append(len(idx))
plt.hist(samples)
plt.xlabel('Number of Samples')
plt.ylabel('Frequency')
plt.title('Histogram for number of samples for level of degree')
# Out:
# Text(0.5, 1.0, 'Histogram for number of samples for level of degree')

# %%
Results = list()
# Field number
f=2
# min number of samples
min_samples = 10
for i, field in enumerate(Z_label[f]):
    idx = np.where(Z[:,f] == i)[0]
    if len(idx)>min_samples:
        result = dict()
        accuracy = list()
        y_ = list()
        for i, (train_index, test_index) in enumerate(kf.split(idx)):
            clf = GaussianNB()
            X_train = X[idx[train_index]][:,:-2]

            for k in range(len(Z_label)):
                if k != f:
                    X_train = np.hstack((X_train, get_ohv(Z[idx[train_index]],Z, k)))
#             clf.fit(np.hstack((X[idx[train_index]][:,:-2], Z[idx[train_index]][:,:f], Z[idx[train_index]][:, f+1:])), \
#                     Y[idx[train_index]])
            clf.fit(X_train, Y[idx[train_index]])
            X_test = X[idx[test_index]][:,:-2]
            for k in range(len(Z_label)):
                if k != f:
                    X_test = np.hstack((X_test, get_ohv(Z[idx[test_index]],Z,k)))
#             accuracy.append(clf.score(np.hstack((X[idx[test_index]][:,:-2], \
#                                                  Z[idx[test_index]][:,:f], \
#                                                 Z[idx[test_index]][:, f+1:])), Y[idx[test_index]]))
            accuracy.append(clf.score(X_test, Y[idx[test_index]]))
            y_.append(np.sum(Y[idx[train_index]]==1)/len(train_index))
        result['field'] = field
        result['Mean Accuracy'] = np.mean(accuracy)*100
        result['Max Accuracy'] = np.max(accuracy)*100
        result['Std Dev'] = np.std(accuracy)*100
        result['Number of samples'] = len(idx)
        result['verbose']= "{0}: \n Number of samples: {1} Mean Accuracy: {2:.3f}% Std dev: {3:.3f}% Max Accuracy {4:.3f}% \n".\
              format(field, len(idx), np.mean(accuracy)*100, np.std(accuracy)*100, np.max(accuracy)*100)
        result['% Lable'] = np.mean(y_)
        Results.append(result)
Results = sorted(Results, key=lambda x : x['Max Accuracy'], reverse=True)
print('Degree level with highest max accuracy')
for i in range(3):
    print(Results[i]['verbose'])
    print(Results[i]['% Lable'])
Results = sorted(Results, key=lambda x : x['Mean Accuracy'], reverse=True)
print("--------------------------\n--------------------------")
print('Degree level with highest mean accuracy')
for i in range(3):
    print(Results[i]['verbose'])
    print(Results[i]['% Lable'])
# Out:
# Degree level with highest max accuracy
# Other:
#  Number of samples: 13 Mean Accuracy: 55.000% Std dev: 47.170% Max Accuracy 100.000%
#
# 0.2303030303030303
# Masters:
#  Number of samples: 66 Mean Accuracy: 25.714% Std dev: 23.995% Max Accuracy 85.714%
#
# 0.6211016949152544
# Ph D:
#  Number of samples: 1261 Mean Accuracy: 28.544% Std dev: 5.857% Max Accuracy 36.508%
#
# 0.4670907240363921
# --------------------------
# --------------------------
# Degree level with highest mean accuracy
# Other:
#  Number of samples: 13 Mean Accuracy: 55.000% Std dev: 47.170% Max Accuracy 100.000%
#
# 0.2303030303030303
# Ph D:
#  Number of samples: 1261 Mean Accuracy: 28.544% Std dev: 5.857% Max Accuracy 36.508%
#
# 0.4670907240363921
# Masters:
#  Number of samples: 66 Mean Accuracy: 25.714% Std dev: 23.995% Max Accuracy 85.714%
#
# 0.6211016949152544
